# %% [markdown]
# # Payer Model with XGBoost
# _**Using Gradient Boosted Trees to Predict Client Insurance Payers**_
#
# ---
# ---
#
# ## Contents

# %%
import sys

# !{sys.executable} -m pip install sagemaker pandas numpy xgboost --upgrade
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.74.0)
# Collecting sagemaker
#   Downloading sagemaker-2.77.1.tar.gz (513 kB)
#      |████████████████████████████████| 513 kB 7.7 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.1.5)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.19.5)
# Collecting xgboost
#   Downloading xgboost-1.5.2-py3-none-manylinux2014_x86_64.whl (173.6 MB)
#      |████████████████████████████████| 173.6 MB 4.0 kB/s
# Requirement already satisfied: attrs==20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3>=1.20.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.20.46)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas) (2021.1)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost) (1.5.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.20.21->sagemaker) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.20.21->sagemaker) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.46 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.20.21->sagemaker) (1.23.46)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.24.0,>=1.23.46->boto3>=1.20.21->sagemaker) (1.26.7)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.77.1-py2.py3-none-any.whl size=711661 sha256=bd7e07b638df857ebcf36a336522d87e3cde6e8e17e8949b872009d94a46b131
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/dc/d8/d1/2e5e90c759d53e76964a7eec7b651107a5e430ec5f04caddda
# Successfully built sagemaker
# Installing collected packages: xgboost, sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.74.0
#     Uninstalling sagemaker-2.74.0:
#       Successfully uninstalled sagemaker-2.74.0
# Successfully installed sagemaker-2.77.1 xgboost-1.5.2

# %%
import sagemaker

sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = "sagemaker/WiEco-Payer-Model"

# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import os
import sys
import time
import json
from IPython.display import display
from time import strftime, gmtime
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

# %% [markdown]
# ---
# ## Data Processing

# %%
# MotionMD Data
momd_pa_types = {
    'momd_pa' : str,
    'momd_clinic_id' : str,
    'momd_clinic_zip' : str,
    'momd_payer_name' : str,
    'momd_payer_position' : str,
    'momd_payer_type' : str,
    'momd_insureds_policy_prefix' : str
}

momd_pa_cols = [
    'momd_pa',
    'momd_clinic_id',
    'momd_clinic_zip',
    'momd_payer_name',
    'momd_payer_position',
    'momd_payer_type',
    'momd_insureds_policy_prefix'
]

momd_df = pd.read_csv("s3://nathan.ml/mike.data.dump/2021-02-24-MotionMD.csv", dtype=momd_pa_types, usecols=momd_pa_cols)

# %%
momd_df
# Out:
#         momd_pa momd_clinic_id momd_clinic_zip  \
# 0       4139454         295247           33542
# 1       4356998         621901           33544
# 2       2908431         295247           33542
# 3       2908431         295247           33542
# 4       2910494         295247           33542
# ...         ...            ...             ...
# 843619  5387846        3577632           83301
# 843620  5388086        3577632           83301
# 843621  5106501        3577632           83301
# 843622  4986734        3577632           83301
# 843623  4986734        3577632           83301
#
#                                           momd_payer_name momd_payer_position  \
# 0                                    WELLCARE URGENT CARE                   1
# 1                         SIMPLY MEDICAID HMO URGENT CARE                   1
# 2       UHC DUAL CHOICE PRIMARY PPO/HMO/MEDICARE SOLUTION                   1
# 3                       UHC DUAL CHOICE SECONDARY PPO/HMO                   2
# 4                    UHC MEDICARE SOLUTIONS ADVANTAGE PPO                   1
# ...                                                   ...                 ...
# 843619                             BC/BS OUT OF STATE PPO                   1
# 843620                            BLUE CROSS OF IDAHO PPO                   1
# 843621                        SLHP UHC MEDICARE ADVANTAGE                   1
# 843622                             BLUE CROSS BLUE SHIELD                   1
# 843623                             BLUE CROSS BLUE SHIELD                   1
#
#        momd_payer_type momd_insureds_policy_prefix
# 0           COMMERCIAL                         160
# 1             MEDICAID                         717
# 2             MEDICARE                         114
# 3           COMMERCIAL                         114
# 4             MEDICARE                         966
# ...                ...                         ...
# 843619      COMMERCIAL                         AQK
# 843620      COMMERCIAL                         XMF
# 843621      COMMERCIAL                         918
# 843622      COMMERCIAL                         123
# 843623      COMMERCIAL                         123
#
# [843624 rows x 7 columns]

# %%
# DataWorks Data

dw_pa_cols = {
    'Ppa',
    'Number'
}

dw_pa_types = {
    'Ppa': str,
    'Number': str
}

#dw_df = pd.read_csv("s3://nathan.ml/mike.data.dump/2021-02-24-Dataworks.csv", usecols=dw_pa_cols, dtype=dw_pa_types)
dw_df = pd.read_csv("s3://nathan.ml/mike.data.dump/2021-02-24-Dataworks.csv", 
                    encoding='utf-16', 
                    delim_whitespace=True,
                    usecols=dw_pa_cols,
                    dtype=dw_pa_types)
dw_df = dw_df.rename(columns={'Ppa':'ppa_number', 'Number':'payer_id'})

# %%
dw_df
# Out:
#           ppa_number payer_id
# 0       Z34685002345    D3982
# 1       Y00000049858      D88
# 2       T30584700419    D8602
# 3       T28249102882     D107
# 4       O00000045411     D218
# ...              ...      ...
# 555704       1679247     D128
# 555705       1588042     D138
# 555706       1573786      UNK
# 555707       1475870     D138
# 555708       1327508     D608
#
# [555709 rows x 2 columns]

# %%
df = pd.merge(momd_df, dw_df, left_on=["momd_pa"], right_on=["ppa_number"], how='inner')
df
# Out:
#         momd_pa momd_clinic_id momd_clinic_zip  \
# 0       2908431         295247           33542
# 1       2908431         295247           33542
# 2       2915859         295247           33542
# 3       2922040         295247           33542
# 4       2922040         295247           33542
# ...         ...            ...             ...
# 486108  5230952        3577632           83301
# 486109  5230952        3577632           83301
# 486110  5244999        3577632           83301
# 486111  5274425        3577632           83301
# 486112  5387846        3577632           83301
#
#                                           momd_payer_name momd_payer_position  \
# 0       UHC DUAL CHOICE PRIMARY PPO/HMO/MEDICARE SOLUTION                   1
# 1                       UHC DUAL CHOICE SECONDARY PPO/HMO                   2
# 2                                                   AVMED                   1
# 3                                         MEDICARE PART B                   1
# 4                                    WPS TRICARE FOR LIFE                   2
# ...                                                   ...                 ...
# 486108                              MEDICARE PART A \T\ B                   1
# 486109                               TRICARE FOR LIFE/WPS                   2
# 486110                        SLHP UHC MEDICARE ADVANTAGE                   1
# 486111                             BC/BS OUT OF STATE PPO                   1
# 486112                             BC/BS OUT OF STATE PPO                   1
#
#        momd_payer_type momd_insureds_policy_prefix ppa_number payer_id
# 0             MEDICARE                         114    2908431      UNK
# 1           COMMERCIAL                         114    2908431      UNK
# 2           COMMERCIAL                         A53    2915859    D8870
# 3             MEDICARE                         5K9    2922040    M0003
# 4           COMMERCIAL                         000    2922040    M0003
# ...                ...                         ...        ...      ...
# 486108        MEDICARE                         4VW    5230952    M0004
# 486109      COMMERCIAL                         535    5230952    M0004
# 486110      COMMERCIAL                         977    5244999    D5172
# 486111      COMMERCIAL                         AQK    5274425     D124
# 486112      COMMERCIAL                         AQK    5387846     D124
#
# [486113 rows x 9 columns]

# %%
#Move Dependent Variable Column to Front
df = df[ ['payer_id'] + [ col for col in df.columns if col != 'payer_id' ] ]
# Get rid of duplicate id column
df = df.iloc[:,:-1]
df = df.dropna(axis=0)

#Data Cleanup (from Moana)
TOLERANCE = 10 # Lower values are more forgiving

print(df.shape, df['payer_id'].nunique())

numm = pd.DataFrame(df.groupby('payer_id').size(),columns = ['size'])
df = pd.merge(df,numm,left_on = 'payer_id', right_on = numm.index)
df = df.loc[df['size']>=TOLERANCE]
df.drop(columns=['size'],inplace=True)

print(df.shape, df['payer_id'].nunique())

df
# Out:
# (486066, 8) 1012
# (484755, 8) 638
#        payer_id  momd_pa momd_clinic_id momd_clinic_zip  \
# 0           UNK  2908431         295247           33542
# 1           UNK  2908431         295247           33542
# 2           UNK  3223847         295247           33542
# 3           UNK  3945007         295247           33542
# 4           UNK  4037998         295247           33542
# ...         ...      ...            ...             ...
# 486061     D323  5163267         360389           38242
# 486062     D323  4726794         360389           38242
# 486063     D323  4726794         360389           38242
# 486064     D323  4886468         360389           38242
# 486065     D323  4886754         360389           38242
#
#                                           momd_payer_name momd_payer_position  \
# 0       UHC DUAL CHOICE PRIMARY PPO/HMO/MEDICARE SOLUTION                   1
# 1                       UHC DUAL CHOICE SECONDARY PPO/HMO                   2
# 2                                           AETNA PPO/POS                   1
# 3                        UHC GROUP MEDICARE ADVANTAGE PPO                   1
# 4                      AARP/UHC MEDICARE COMPLETE/HMO/PPO                   1
# ...                                                   ...                 ...
# 486061                                            WINDSOR                   1
# 486062                                            WINDSOR                   1
# 486063                                  MEDICAID/BLUECARE                   2
# 486064                                            WINDSOR                   1
# 486065                                            WINDSOR                   1
#
#        momd_payer_type momd_insureds_policy_prefix
# 0             MEDICARE                         114
# 1           COMMERCIAL                         114
# 2           COMMERCIAL                         W17
# 3             MEDICARE                         972
# 4             MEDICARE                         903
# ...                ...                         ...
# 486061      COMMERCIAL                         316
# 486062      COMMERCIAL                         313
# 486063        MEDICAID                         TD5
# 486064      COMMERCIAL                         182
# 486065      COMMERCIAL                         293
#
# [484755 rows x 8 columns]

# %% [markdown]
# ---
# ## Encoding of Model
# ### Done so the data can be trained using XGBoost

# %%
from sklearn import model_selection
from sklearn.preprocessing import LabelEncoder
# Encode string class values as integers (needed for XGBoost)
le = LabelEncoder()
df_encoded = df
for col in df:
    df_encoded[col] = le.fit_transform(df[col])
df_encoded
# Out:
#         payer_id  momd_pa  momd_clinic_id  momd_clinic_zip  momd_payer_name  \
# 0            637     3356             193              305            10952
# 1            637     3356             193              305            10953
# 2            637    43569             193              305              792
# 3            637   137890             193              305            10976
# 4            637   149908             193              305              306
# ...          ...      ...             ...              ...              ...
# 486061       280   313607             599              392            12716
# 486062       280   251571             599              392            12716
# 486063       280   251571             599              392             7665
# 486064       280   274949             599              392            12716
# 486065       280   274990             599              392            12716
#
#         momd_payer_position  momd_payer_type  momd_insureds_policy_prefix
# 0                         0                3                          148
# 1                         4                1                          148
# 2                         0                1                        13943
# 3                         0                3                         5908
# 4                         0                3                         5836
# ...                     ...              ...                          ...
# 486061                    0                1                         1589
# 486062                    0                1                         1586
# 486063                    4                2                        13090
# 486064                    0                1                          230
# 486065                    0                1                          961
#
# [484755 rows x 8 columns]

# %%
payer_id = df_encoded.iloc[:, 0]
print(f'NumClasses: {len(np.unique(payer_id))}')
# Out:
# NumClasses: 638

# %%
# get the training and validation data with a 80% split
train_data, validation_data = np.split(df.sample(frac=1, random_state=1077), [int(0.8 * len(df))]) 
train_data.shape, validation_data.shape
# Out:
# ((387804, 8), (96951, 8))

# %% [markdown]
# ---
# ## Training in AWS

# %%
# turn the training and testing data into csv files
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)

# %%
# upload training and testing data to bucket
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')

# %%
#Grab XGBoost container
container = sagemaker.image_uris.retrieve('xgboost', boto3.Session().region_name, '1')
display(container)
# Out:
# '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'

# %%
s3_input_train = TrainingInput(
    s3_data="s3://{}/{}/train".format(bucket, prefix), content_type="csv"
)
s3_input_validation = TrainingInput(
    s3_data="s3://{}/{}/validation/".format(bucket, prefix), content_type="csv"
)

# %%
common_training_params = \
{
    "AlgorithmSpecification": {
        "TrainingImage": container,
        "TrainingInputMode": "File"
    },
    "RoleArn": role,
    "OutputDataConfig": {
        "S3OutputPath": "s3://{}/{}/ouput".format(bucket, prefix)
    },
    "ResourceConfig": {
        "InstanceCount": 1,   
        "InstanceType": "ml.m4.xlarge",
        "VolumeSizeInGB": 10
    },
    "HyperParameters": {
        "max_depth":"40",
        "eta":"0.02",
        "num_round":"200",
        "sample_type":"weighted",
        "silent":"0",
        "subsample":"0.8",
        "objective": "multi:softprob",
        "num_class": str(len(df['payer_id'].unique()))
    },
    "StoppingCondition": {
        "MaxRuntimeInSeconds": 3600*30
    },
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": "s3://{}/{}/train".format(bucket, prefix),
                    "S3DataDistributionType": "FullyReplicated" 
                }
            },
            "ContentType": "csv",
            "CompressionType": "None"
        },
        {
            "ChannelName": "validation",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": "s3://{}/{}/validation".format(bucket, prefix),
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "ContentType": "csv",
            "CompressionType": "None"
        }
    ]
}

# %%
training_job_name = 'training-job' 
print("Job name is:", training_job_name)
import copy
training_job_params = copy.deepcopy(common_training_params)
training_job_params['TrainingJobName'] = training_job_name
# Out:
# Job name is: training-job

# %%
# %%time
#Run Training Job
sm = boto3.Session(region_name=boto3.Session().region_name).client('sagemaker')
sm.create_training_job(**training_job_params)
# Out:
# CPU times: user 211 ms, sys: 8.79 ms, total: 219 ms
# Wall time: 413 ms
# {'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:173971985270:training-job/training-job',
#  'ResponseMetadata': {'RequestId': '6178ba2b-0cb5-4d86-996a-85d639088662',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6178ba2b-0cb5-4d86-996a-85d639088662',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '87',
#    'date': 'Fri, 04 Mar 2022 23:50:14 GMT'},
#   'RetryAttempts': 0}}

# %%
#Status/Warnings
status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
while status=='InProgress':
    status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
    print("Status: " + status)
    time.sleep(60)
# Out:
# Status: InProgress
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-841f3b4de425> in <module>
#       4     status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
#       5     print("Status: " + status)
# ----> 6     time.sleep(60)
#
# KeyboardInterrupt:

# %%
#Status/Warnings
import boto3
training_job_name = 'training-job' 
sm = boto3.Session(region_name=boto3.Session().region_name).client('sagemaker')
status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
while status=='InProgress':
    status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
    print("Status: " + status)
    #time.sleep(60)
# Out:
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# Status: InProgress
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6074d9992221> in <module>
#       5 status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
#       6 while status=='InProgress':
# ----> 7     status = sm.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
#       8     print("Status: " + status)
#       9     #time.sleep(60)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     704         else:
#     705             http, parsed_response = self._make_request(
# --> 706                 operation_model, request_dict, request_context)
#     707
#     708         self.meta.events.emit(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     723     def _make_request(self, operation_model, request_dict, request_context):
#     724         try:
# --> 725             return self._endpoint.make_request(operation_model, request_dict)
#     726         except Exception as e:
#     727             self.meta.events.emit(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     102         logger.debug("Making request for %s with params: %s",
#     103                      operation_model, request_dict)
# --> 104         return self._send_request(request_dict, operation_model)
#     105
#     106     def create_request(self, params, operation_model=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     137             request, operation_model, context)
#     138         while self._needs_retry(attempts, operation_model, request_dict,
# --> 139                                 success_response, exception):
#     140             attempts += 1
#     141             # If there is a stream associated with the request, we need
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     264             logger.debug("Response received to retry, sleeping for "
#     265                          "%s seconds", handler_response)
# --> 266             time.sleep(handler_response)
#     267             return True
#     268
#
# KeyboardInterrupt:
